# %%
"""
Programa adulto
Descrição: Este programa pergunta a idade de uma pessoa.
Se a idade for maior do que 18 anos, o programa imprime
na tela o texto "Oi! Você e um adulto."
Autor: Felipe
Data: 24/03/2026
Versão: 0.0.1
"""
# Out:
# '\nPrograma adulto\nDescrição: Este programa pergunta a idade de uma pessoa.\nSe a idade for maior do que 18 anos, o programa imprime\nna tela o texto "Oi! Você e um adulto."\nAutor: Nelson\nData: 24/03/2026\nVersão: 0.0.1\n'

# %%
# Alocação de memória

idade = 0
texto = ""

# %%
# Entrada de dados

idade = int(input("\nQual é a sua idade?"))

# %%
# Processamento de dados

if idade >= 18:
    texto = "Oi! Você é um adulto."
elif idade >= 14 < 18:
    texto = "Você é um adolescente! Segura firme!!!"
else:
    texto = "Você é uma criança! Suma!!!"

# %%
# Saída de dados

print(texto)
# Out:
# Você é um adolescente! Segura firme!!!
