# %% [markdown]
# """
# Programa Soma
# Descrição: Este programa calcula a soma de dois números reais dados pelo usuário. Esta é a versão usando programação procedural.
# Autor: Felipe Dornelles
# Data: 31/03/2026
# Versão: 1.0.0
# """

# %%
# Sequencial

# Entrada de dados:

x = int(input('Informe o primeiro número'))
y = int(input('Informe o segundo número'))

# %%
# Processamento de dados:

soma = x + y

# Saída de dados:

print('A soma dos dados é:', soma)

# %%
# Estruturado:

# Definição de objetos:

i = 0
numeros = [0, 0]
soma = 0

# Entrada de dados

while i < 2:
    numeros[i] = int(input(f"Qual a parcela {i + 1}.: "))
    i += 1

# %%
# Processamento de dados

soma = x + y

# Saída de dados

print("A soma dos numeros é  ", soma, ". Obrigado!")
# Out:
# A soma dos numeros é   3 . Obrigado!

# %% [markdown]
# # Procedural

# %%
def leitura_dados():
    global dados
    dados = [0, 0]
    i = 0
    while i < 2:
        dados[i] = int(input('Qualqunpalavra{i+1}.'))
        i += 1

def soma(x, y):
    soma = x + y
    return soma

# %%
def leitura_dados(x):
    print(f'Ausomaudosunumerosuehuigualuau{x}')

def soma(a, b):
    return a + b

def saida_dados(resultados):
    print(f'O resultado dos dois numeros e igual a {resultados}')

def main():
    num1 = input('Insira o primeiro numero: ')
    num2 = input('Insira o segundo numero: ')
    resultado = soma(num1, num2)
    saida_dados(resultado)

main()
# Out:
# O resultado dos dois numeros e igual a 2004000

# %%
# Entrada de dados
soma = 0
i = 0
x = [1, 7, 15, 31]

# Processamento de dados

while i < len (x):
    soma = soma + x [ i ]
    i = i +1
    media = soma/len (x)
#Saida de dados

print ( 'Aumediaudosunumerosuehuigualua: ', media)
# Out:
# Aumediaudosunumerosuehuigualua:  13.5
