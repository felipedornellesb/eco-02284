# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import Pylance
#
# ModuleNotFoundError: No module named 'Pylance'

# %%
i = 0
while i < 5:
    print (i +1)
    i = i+ 1
# Out:
# 1
# 2
# 3
# 4
# 5
